# %% [markdown]
# #Pitch Classification Models
#
# https://github.com/brettcastro2004/Pitch-Classification-Model
#
#
# This is a pitch classification model featuring data cleaning, normalization, correlation and feature visualization, KNN, ANN, PCA, and an ensemble model.
# This model was created by Brett Castro and Paulo Julio. See the github link above for more information and dataset access.

# %% [markdown]
# # Background
# This project involves building classification models that examine pitch characteristics and labels a given pitch into one of 8 categories. We utilize pitching data provided by MLB and Statcast through Baseball Savant. The model will be evaluated based on its ability to accurately classify the type of pitch thrown based on its physical behavior. Given that there are hundreds of pitchers in MLB who each throw with different characteristics, we aim to create a generalized model that is able to classify pitches with a moderately high accuracy.
#
# Sam Sharpe writes about MLB’s own patented classification system in a breakdown article, “MLB pitch classification”. Here, he describes the multilayered model, PitchNet, which first considers a generic pitching model, moves through a pitcher specific model which compares the predicted pitch to the player’s repertoire, and considers other factors such as weather and climate data in its prediction. That model utilizes both supervised and unsupervised learning to achieve a 97% or higher accuracy. We reiterate that our model intends to only fulfill the first layer, a generic pitch model that labels a pitch given purely mechanical properties of the pitch.
#
# # Dataset Description
#
# To ensure a good set of data, we use Baseball Savant. Baseball Savant is directly owned by MLB and is the home for Statcast, a database for every game, at-bat, and pitch thrown in an entire season, which amounts to hundreds of millions of data points. It is accessible here:
#
# https://baseballsavant.mlb.com/statcast\_search
#
# The full implementation of the Statcast system is explained in the article “Introducing Statcast 2020: Hawk-Eye and Google Cloud” by Ben Jedlovec. In short, this system uses cameras and radar technology to track swings, baserunners, thrown balls, and pitches. It is the system MLB uses for their own systems, and assures us that the data we use will be high quality.
#
# The dataset consists of tabular data and includes detailed measurements of individual pitches. We intend to use only 40,000 pitches worth of data to train the model, with 5000 instances per pitch type. This number gives us data from hundreds of pitchers, and preferably keeps us from considering too much noise or overtraining the models.
#
# The features we will be utilizing for classification include: velocity, spin rate, horizontal movement (pfx_x), vertical movement (pfx_z), and spin axis. To fully understand what these features mean in the context of a basesball game, we can encourage looking through the official documentation:
#
# https://baseballsavant.mlb.com/csv-docs
#
# Though there are more pitches in existence, the pitches we will consider for labeling are four-seam fastball, sinker, sweeper, slider, cutter, curveball, splitter and changeup.
#
# The models themselves will be a K nearest neighbors model and an artificial neural network. We will also conduct PCA and rerun the models using the reduced feature space. To conclude, an ensemble model composed of both the KNN and ANN models will be created, with the intention of acheiving the highest accuracy of all models.
#
# To begin, we must first analyze the features themselves. We start by examining the correlation between features, and after seeing how the features relate to one another, we will create a hypothesis for how the models might behave.

# %%
# Importing all libraries

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# #Data Gathering & Normalization
#
# We begin by gathering 5000 clean samples of data from each of the 8 pitch type datasets (originally containing 25000 each).
#
# *Identifying and Handling Missing Data*
#
# Due to how precise pitches are, we cannot classify any pitches that are missing data. Thus, we remove any pitches that are missing data for any of our 5 features from the working dataset.
#
# We normalize that data to only consider right handed pitchers (in order to avoid any issues due to differences between right and left handed pitchers). To avoid excluding left handed pitchers altogether, we can essentially turn their pitches into right handed pitches, accomplished by flipping all horizontal movement for lefties (positive values all become negative and vice versa). We then must mirror the spin axis (measured in degrees) using (new axis = (360 - old axis) % 360). All data will then be normalized using z-score normalization. The resulting dataframe is also stored as a csv file.

# %%
folder_path = "/content/data"

columns_needed = [
    "pitch_type",
    "player_name",
    "release_speed",
    "pfx_x",
    "pfx_z",
    "release_spin_rate",
    "spin_axis",
    "p_throws"
]

hand_col = "p_throws" # Handedness indicator
spin_col = "spin_axis"

numeric_columns = [
    "release_speed",
    "pfx_x",
    "pfx_z",
    "release_spin_rate",
    "spin_axis"
]

csv_files = [
    "four_seam_fastball_data.csv",
    "cutter_data.csv",
    "changeup_data.csv",
    "curveball_data.csv",
    "sinker_data.csv",
    "slider_data.csv",
    "splitter_data.csv",
    "sweeper_data.csv"
]

output_csv = 'normalized_pitch_data.csv'

df = pd.DataFrame()

NUM_ROWS = 5000  # Desired rows per pitch type

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    print(f"\nProcessing: {file}")

    clean_rows = []

    # Read in chunks of 1000 rows to ensure 5000 of each type
    file_chunk = pd.read_csv(file_path, chunksize=1000)

    # Clean data
    for chunk in file_chunk:
        chunk = chunk[columns_needed]
        chunk = chunk.replace([float("inf"), float("-inf")], pd.NA)
        chunk = chunk.dropna()
        clean_rows.append(chunk)

        # Stop if we have enough clean rows (5000)
        total_clean = sum(len(x) for x in clean_rows)
        if total_clean >= NUM_ROWS:
            break

    combined = pd.concat(clean_rows, ignore_index=True)

    # Enforce EXACTLY 5000 rows
    combined = combined.head(NUM_ROWS)
    print(f"Clean rows collected: {len(combined)}")
    df = pd.concat([df, combined], ignore_index=True)

# Normalize handedness (mirror lefties)
left_mask = df[hand_col].str.upper() == "L"
df.loc[left_mask, "pfx_x"] = -df.loc[left_mask, "pfx_x"]

# Mirror spin axis: new_axis = (360 - old_axis) % 360
df.loc[left_mask, spin_col] = (360 - df.loc[left_mask, spin_col]) % 360

print(f"\nPitches mirrored: {left_mask.sum()}")

# Keep an unnormalized dataframe for feature analysis
unnorm_df = df.copy(deep=True)

# Normalize numeric features (z-score)
scaler = StandardScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# Save dataframe to csv
df.to_csv(output_csv, index=False)
print(f"Saved to: {output_csv}")
# Out:
# Processing: four_seam_fastball_data.csv
# Clean rows collected: 5000
#
# Processing: cutter_data.csv
# Clean rows collected: 5000
#
# Processing: changeup_data.csv
# Clean rows collected: 5000
#
# Processing: curveball_data.csv
# Clean rows collected: 5000
#
# Processing: sinker_data.csv
# Clean rows collected: 5000
#
# Processing: slider_data.csv
# Clean rows collected: 5000
#
# Processing: splitter_data.csv
# Clean rows collected: 5000
#
# Processing: sweeper_data.csv
# Clean rows collected: 5000
#
# Pitches mirrored: 10721
# Saved to: normalized_pitch_data.csv

# %% [markdown]
# # Dataset Analysis and Visualization
#
# We are now going to use a heatmap to visually display the linear correlation between features. We see that there is a strong positive correlation between vertical movement (pfx_z) and release speed, spin rate and horizontal movement (pfx_x), release speed and spin axis, and spin axis and vertical movement. Conversely, there is a strong negative correlation between horizontal movement and spin axis, release speed, and vertical movement, as well as spin axis and spin rate. Release speed and vertical movement both have a weak correlation with spin rate.
#
# We can examine some of these relationships to create a hypothesis on how the pitches that behave similarly might be confused, as well as seeing how pitch movement is affected by spin rate, velocity, and spin axis.

# %%
# Create correlation matrix plot
plt.figure(figsize=(8,6))
corr = df[numeric_columns].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Dataset Correlation Matrix")
plt.show()

# %% [markdown]
# # Spin Axis vs Horizontal Break
#
# We first examine the effect of spin axis on horizontal movement, the most negatively correlated relationship. We are particularly looking at how certain pitches move towards or away from the pitcher's arm side, and how spin axis affects that movement. To understand how spin axis is described, a helpful chart is found here: https://www.drivelinebaseball.com/wp-content/uploads/2019/09/spin_axis_green_line.webp

# %%
# We examine the effect of spin axis on horizontal movement

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=unnorm_df,
    x="spin_axis",
    y="pfx_x",
    hue="pitch_type",
    alpha=0.6,
    s=20
)
plt.title("Spin Axis vs Horizontal Break")
plt.grid(True)
plt.show()

# %% [markdown]
# We can see from the graph that pitches do indeed have a negative correlation overall when considering spin axis and horizontal movement. A pitch thrown with a more positive spin axis tends to break more negatively horizontal (we describe this as "arm side" movement). A pitch thrown with a less positive spin axis breaks more positively horizontal (called "glove side" movement").
#
#
#
# Looking at other pitch patterns, it is clear that many clusters overlap. Pitches such as changeups, splitters, and sinkers break "arm side," and tend to have a lot of overlap. We see pitches that break to the "glove side" includes curveballs, sweepers, cutters, and sliders. Four-seamers are quite hidden compared to other clusters, and are intended to not break horizontally very much, so their behavior here will mostly be pitcher dependent.

# %% [markdown]
# # Velocity vs Vertical Movement
#
# We now examine how velocity and vertical movement relate to one another.

# %%
# We examine the relationship between velocity and vertical movement

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=unnorm_df,
    x="release_speed",
    y="pfx_z",
    hue="pitch_type",
    alpha=0.6,
    s=20
)
plt.title("Velocity vs Vertical Break")
plt.grid(True)
plt.show()

# %% [markdown]
# The slowest pitch, the curveball, breaks the most vertically, and the fastest pitch in the four-seamer tends to rise slightly due to backspin. Most other pitches tend to move vertically to varying degrees, with a clear positive linear relationship between velocity and vertical break overall. Distinguishable clusters are still maintained here.
#
# This linear trend gives us an idea that the models will want to consider how velocity and vertical movement relate when examining a pitch's characteristics while labeling. This leaves some room for error as pitch types that overlap will need further pattern analysis to be accurately labeled.

# %% [markdown]
# # Spin Rate vs Induced Break
#
# Examining the relationship between spin rate and the magnitude of induced break allows us to see how the ball moves for a given pitch type based on the spin rate that the ball is thrown with.

# %%
# We examine the relationship between total induced break and spin rate

unnorm_df["induced_break"] = np.sqrt(df["pfx_x"]**2 + df["pfx_z"]**2)

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=unnorm_df,
    x="release_spin_rate",
    y="induced_break",
    hue="pitch_type",
    alpha=0.6
)
plt.title("Spin Rate vs Total Induced Break")
plt.grid(True)
plt.show()

# %% [markdown]
# Curveballs break the most out of any pitch type, famously dropping vertically, and also have the highest spin rate with "elite stuff" being near 3000 rpm. Other pitches behave radically different from one another, maintaining clear clusters as spin rate changes. Splitters and changeups have very low spin rates, typically around 1200 rpm, and move by tumbling through the air due to their low spin rate. These pitches can move upwards of 18 inches. Sinkers are more tightly confined, with an average spin rate around 2500 rpm, and average break around 15 inches.
#
# Analyzing this in context gives us an understanding of how break can be produced in different ways. Curveballs break by having a very high spin rate, while splitters and changeups break with a very low spin rate. These stark differences will be very useful for our models to use while learning pitch patterns.

# %% [markdown]
# # Model Strength and Weakness Hypothesis
# Examining these trends in context allows us to compile a complete picture of pitch qualities and form a hypothesis about our classification models. We presume that highly distinguishable pitches like curveballs and four-seam fastballs will be labeled very well, while pitches that overlap in their features, such as changeups and splitters will tend to be confused for one another. We believe this will apply to the following pitch types: CH/FS, FC/SL, SL/ST.

# %% [markdown]
# ---
#
#
# # Training a Model
#
# MLB uses a proprietary system called PitchNet. PitchNet utilizes gradient boosting alongside individual pitcher models layered with ballpark specific weather and climate data to create a prediction of pitch type. For our purposes, we strip back these complexities to create a generic pitcher model that looks purely at physical ball behavior.
#
# Due to many similarities between pitch types physically, a decent model might be in the range of 80% accuracy. To create this system, we will train and test two separate models. The first model will use K Nearest Neighbors, the second will use Artificial Neural Network.
#
# We need to set up a training and test data split, deciding to do 4000 samples as training and 1000 as test data.

# %%
plt.rcParams['figure.dpi'] = 140

X = df[numeric_columns].values

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df["pitch_type"])

classes = label_encoder.classes_
num_classes = len(classes)

# Training split - 4000 training, 1000 testing per pitch type
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    stratify=y,
    random_state=42
)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %% [markdown]
# ## K Nearest Neighbors (KNN)
#
# KNN allows us to compare a given unclassified pitch with K pitches that are most similar to the given one. The model does exactly as it's name implies, looking at the *K* nearest neighbors to the unclassified pitch, then taking a majority vote for the labeling of that pitch.
#
# The first step is setting up the training split. Then, we use KNN via sklearn with a  selection of k = 7, a standard value.

# %%
knn = KNeighborsClassifier(
    n_neighbors=7,
    weights="distance",
    metric="euclidean"
)

knn.fit(X_train_scaled, y_train)

y_pred_knn = knn.predict(X_test_scaled)

acc_knn = accuracy_score(y_test, y_pred_knn)
prec_knn = precision_score(y_test, y_pred_knn, average='macro')
rec_knn = recall_score(y_test, y_pred_knn, average='macro')
f1_knn = f1_score(y_test, y_pred_knn, average='macro')


print(f"\nKNN Accuracy: {acc_knn:.4f}")
print(f"KNN Precision:, {prec_knn:.4f}")
print(f"KNN Recall:, {rec_knn:.4f}")
print(f"KNN F1-score:, {f1_knn:.4f}")

print("\nClassification Report (KNN):")
print(classification_report(y_test, y_pred_knn, target_names=classes))
# Out:
# KNN Accuracy: 0.8340
# KNN Precision:, 0.8333
# KNN Recall:, 0.8340
# KNN F1-score:, 0.8332
#
# Classification Report (KNN):
#               precision    recall  f1-score   support
#
#           CH       0.78      0.76      0.77      1000
#           CU       0.91      0.90      0.91      1000
#           FC       0.79      0.81      0.80      1000
#           FF       0.92      0.93      0.92      1000
#           FS       0.80      0.82      0.81      1000
#           SI       0.91      0.89      0.90      1000
#           SL       0.74      0.67      0.70      1000
#           ST       0.83      0.89      0.86      1000
#
#     accuracy                           0.83      8000
#    macro avg       0.83      0.83      0.83      8000
# weighted avg       0.83      0.83      0.83      8000

# %% [markdown]
# This model achieves 83.4% accuracy on our test data. Looking at the individual pitch types, we see some variance in accuracy. Our precision, recall, and f1 scores suggest that our fastball group is being classified correct the most often, and the model has a good grasp on their characteristics. Breaking and offspeed pitches are being confused more, and sliders especially are being misclassified more than any.
#
# This still appears to be a good result. We can consider the confusion matrix of this model to see what is happening with pitches that are being improperly labeled.

# %%
cm_knn = confusion_matrix(y_test, y_pred_knn)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_knn, display_labels=classes)
plt.figure(figsize=(8,6))
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("KNN Confusion Matrix")
plt.show()

# %% [markdown]
# As we assumed, changeups and splitters, cutters and sliders, and sweepers and sliders are being confused. In particular, splitters are favored over changeups, cutters over sliders, and sweepers over sliders. We also see some confusion between sinkers and four-seamers, as well as four-seamers and cutters. This makes sense, as all 3 are fastballs. We do see that four-seamers as a whole are being well labeled, as well as curveballs, sweepers, then sinkers. Our findings suggest that our hypothesis was correct.

# %% [markdown]
# #WCSS
# To optimize our KNN model, we will be selecting a K value using Within-Cluster Sum of Squares (WCSS). We look for where WCSS stops improving, which is commonly denoted as the "elbow point".

# %%
# Compute WCSS for k
wcss = []
k_values = range(2, 15)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init="auto")
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# Plot the elbow curve
plt.figure(figsize=(8,6))
plt.plot(k_values, wcss, marker="o")
plt.title("Elbow Method for k")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("WCSS (Within-Cluster Sum of Squares)")
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %% [markdown]
# We see from the graph that k = 8 or 9 appears to be where the slopes between points begins to decrease. Now we examine the accuracy of the model, then consider the confusion matrix of the model with this adjustment.

# %%
knn = KNeighborsClassifier(
    n_neighbors=9,
    weights="distance",
    metric="euclidean"
)

knn.fit(X_train_scaled, y_train)

y_pred_knn = knn.predict(X_test_scaled)

acc_knn = accuracy_score(y_test, y_pred_knn)
prec_knn = precision_score(y_test, y_pred_knn, average='macro')
rec_knn = recall_score(y_test, y_pred_knn, average='macro')
f1_knn = f1_score(y_test, y_pred_knn, average='macro')


print(f"\nKNN Accuracy: {acc_knn:.4f}")
print(f"KNN Precision:, {prec_knn:.4f}")
print(f"KNN Recall:, {rec_knn:.4f}")
print(f"KNN F1-score:, {f1_knn:.4f}")

print("\nClassification Report (KNN):")
print(classification_report(y_test, y_pred_knn_up, target_names=classes))
# Out:
# KNN Accuracy: 0.8361
# KNN Precision:, 0.8352
# KNN Recall:, 0.8361
# KNN F1-score:, 0.8351
#
# Classification Report (KNN):
#               precision    recall  f1-score   support
#
#           CH       0.79      0.76      0.78      1000
#           CU       0.91      0.90      0.91      1000
#           FC       0.78      0.81      0.80      1000
#           FF       0.92      0.93      0.92      1000
#           FS       0.81      0.83      0.82      1000
#           SI       0.90      0.89      0.90      1000
#           SL       0.74      0.66      0.70      1000
#           ST       0.83      0.90      0.86      1000
#
#     accuracy                           0.84      8000
#    macro avg       0.84      0.84      0.84      8000
# weighted avg       0.84      0.84      0.84      8000

# %%
cm_knn = confusion_matrix(y_test, y_pred_knn)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_knn, display_labels=classes)
plt.figure(figsize=(8,6))
disp.plot(cmap="Greens", xticks_rotation=45)
plt.title("KNN Confusion Matrix - Updated")
plt.show()

# %% [markdown]
# This is a marginal improvement of <1%. While no pitches were classified differently, the improvement in accuracy means the change should still should be applied. We keep k = 9.
#
# ---

# %% [markdown]
# # Artificial Neural Network (ANN)
# We move to the second model, an ANN. Functionally, the ANN has 5 layers. It first recieves a pitch with 5 normalized features and sees obvious patterns in the data. The first dense layer has 128 neurons, the second 64, the third 32 and the fourth 8. Each layer deeply analyzes patterns within the data, specifically looking at how the features interact. Layer 1 for instance may look at how fastballs (encoded to some integer) tend to have the highest velocity and high spin rate, and that curveballs also have high spin, but low velocity.
#
# As the pitch goes to the next layer, the model keeps examining patterns and refines itself via its activation function. In the final layer, a new activation function, Softmax, considers the outputs of the previous dense layer and converts it into a list of probabilities. The highest probability label is chosen. During training, the loss measures the difference between the probability distribution from the true label, and is used when the optimizer updates the weights of the features. We can use loss, accuracy, and r-squared score to determine how the model is performing.

# %%
# Begin by resetting training split for ANN

X = df[numeric_columns].values

# One hot encode pitch type for ANN
label_encoder = LabelEncoder()
y_int = label_encoder.fit_transform(df["pitch_type"])
y = tf.keras.utils.to_categorical(y_int, num_classes=len(label_encoder.classes_))

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y_int
)

# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# We create the model based off of the provided sample code. After several runs trying various combination of neurons, learning rates, activation functions, and batch sizes, we settle on this setup as the most consistenly well performing. One distinction to note from the sample code is the activation function we chose to use. Instead of using the sigmoid function, we chose softmax for classification. This works for us since our pitch classification model is such that each pitch can only belong to one class. Softmax is specifically designed for cases like this. In the article "*Multi-label classification for beginners with codes,*" Mehul Gupta explains this, "Sigmoid is preferred for multilabel classification because it allows for independent probabilities for each label, while softmax is designed for exclusive class assignments, such as in multiclass classification."  Our case is exactly this, so we use softmax.
#
#
# https://medium.com/data-science-in-your-pocket/multi-label-classification-for-beginners-with-codes-6b098cc76f99

# %%
# Create model based off of sample code, modified to our application using tensorflow instead of sklearn

ann = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.1),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.1),

    Dense(32, activation='relu'),
    BatchNormalization(),

    Dense(len(label_encoder.classes_), activation='softmax')
])

ann.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Build model and run

history = ann.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7055 - loss: 0.3804 - val_accuracy: 0.8066 - val_loss: 0.1178
# Epoch 2/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7825 - loss: 0.1325 - val_accuracy: 0.8112 - val_loss: 0.1106
# Epoch 3/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7915 - loss: 0.1262 - val_accuracy: 0.8136 - val_loss: 0.1087
# Epoch 4/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7981 - loss: 0.1224 - val_accuracy: 0.8147 - val_loss: 0.1058
# Epoch 5/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7998 - loss: 0.1198 - val_accuracy: 0.8114 - val_loss: 0.1081
# ...

# %%
test_loss, test_acc = ann.evaluate(X_test, y_test, verbose=0)
print(f"\nANN Test Accuracy: {test_acc:.4f}")

y_pred_ann = ann.predict(X_test)
y_pred_labels_ann = np.argmax(y_pred_ann, axis=1)
y_true_labels_ann = np.argmax(y_test, axis=1)

print("\nClassification Report:")
print(classification_report(y_true_labels_ann, y_pred_labels_ann, target_names=label_encoder.classes_))
# Out:
# ANN Test Accuracy: 0.8341
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           CH       0.76      0.80      0.78      1000
#           CU       0.90      0.91      0.90      1000
#           FC       0.78      0.79      0.79      1000
#           FF       0.91      0.94      0.93      1000
#           FS       0.84      0.79      0.81      1000
#           SI       0.92      0.87      0.90      1000
#           SL       0.72      0.69      0.70      1000
#           ST       0.84      0.88      0.86      1000
#
#     accuracy                           0.83      8000
#    macro avg       0.83      0.83      0.83      8000
# weighted avg       0.83      0.83      0.83      8000

# %% [markdown]
# Accuracy is very slightly lower than the KNN model. We observe a high accuracy of classification for curveballs, four-seam fastballs, and sinkers. We see that the accuracy of some pitch types such as changeups and sliders is also low in this model, and we now consider the confusion matrix to see where the discrepancies lie.

# %%
cm_ann = confusion_matrix(y_true_labels_ann, y_pred_labels_ann)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_ann, display_labels=classes)
plt.figure(figsize=(8,6))
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("ANN Confusion Matrix")
plt.show()

# %% [markdown]
# The same pitch types from the KNN model are being misclassified. This model tends to favor changeups over splitters, does even better with fastballs, and does better with some breaking pitches like sliders, but worse with sweepers, cutters, and sinkers. This seems to imply that the models have different strenghths, which foreshadows a possible solution that incorporates elements of both to create a stronger model.
#
#
#
# ---

# %% [markdown]
# #PCA (Principal Component Analysis)
#
# Before we move to an ensemble model, we first want to consider what happens if we move from the sample space to principal component space. Our question is whether or not condensing our features from 5 to 2 will be more accurate in our models. We hypothesize that removing features from the sample space will ultimately result in a less accurate model due to the evident relationships between features within our pitch data.
#
# To conduct PCA we ensure our training split is clean, convert the data to PCA space, and train the KNN and ANN models using the same parameters as before.

# %%
X = df[numeric_columns].values

label_encoder = LabelEncoder()
y_int = label_encoder.fit_transform(df["pitch_type"])
y = tf.keras.utils.to_categorical(y_int)

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y_int
)

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s  = scaler.transform(X_test)

# PCA to 2 components
pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_s)
X_test_pca  = pca.transform(X_test_s)

# %%
knn_pca = KNeighborsClassifier(
    n_neighbors=9,
    weights="distance",
    metric="euclidean"
    )
knn_pca.fit(X_train_pca, np.argmax(y_train, axis=1))

y_pred_knn_pca = knn_pca.predict(X_test_pca)

acc_knn_pca = accuracy_score(np.argmax(y_test, axis=1), y_pred_knn_pca)
print(f"\nKNN PCA Accuracy: {acc_knn_pca:.4f}")


print("\nClassification Report (KNN PCA):")
print(classification_report(np.argmax(y_test, axis=1), y_pred_knn_pca, target_names=classes))
# Out:
# KNN PCA Accuracy: 0.6661
#
# Classification Report (KNN PCA):
#               precision    recall  f1-score   support
#
#           CH       0.58      0.60      0.59      1000
#           CU       0.78      0.78      0.78      1000
#           FC       0.70      0.72      0.71      1000
#           FF       0.75      0.72      0.73      1000
#           FS       0.68      0.66      0.67      1000
#           SI       0.65      0.67      0.66      1000
#           SL       0.59      0.52      0.55      1000
#           ST       0.61      0.66      0.63      1000
#
#     accuracy                           0.67      8000
#    macro avg       0.67      0.67      0.67      8000
# weighted avg       0.67      0.67      0.67      8000

# %% [markdown]
# As we predicted, we see a significantly lower accuracy in classification using PCA compared to using the full feature space in KNN. In particular, it appears that breaking pitches and off speed pitches are hurt the most. Our precision, recall, and f1 scores support this idea, showing that the model is not understanding how the pitches differ, and thus is not able to distingush pitch types well.
#
# Let's look at the confusion matrix to confirm this.

# %%
cm_knn = confusion_matrix(np.argmax(y_test, axis=1), y_pred_knn_pca)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_knn, display_labels=classes)
plt.figure(figsize=(8,6))
disp.plot(cmap="Oranges", xticks_rotation=45)
plt.title("KNN Confusion Matrix - PCA")
plt.show()

# %% [markdown]
# The confusion matrix indeed confirms that all pitches are being incorrectly classified at a higher rate. We can analyze specific relationships. Changeups and splitters are again confused the most, a trend that is inflated from the standard KNN model. The pitches with the largest break, curveballs and sweepers, are also now being confused at a high rate. This implies that PCA is merging horizontal and vertical break, resulting in a huge loss of accuracy. We see similar trends between cutters and sliders, as well as sinkers and four-seam fastballs.
#
# We can now analyze PCA with the ANN to see if this trend carries over between models.

# %%
ann_pca = Sequential([
    Dense(128, activation='relu', input_shape=(2,)),
    BatchNormalization(),
    Dropout(0.1),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.1),

    Dense(32, activation='relu'),
    BatchNormalization(),

    Dense(len(label_encoder.classes_), activation='softmax')

])

ann_pca.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="mse",
    metrics=["accuracy"]
)

history_pca = ann_pca.fit(
    X_train_pca, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6054 - loss: 0.0657 - val_accuracy: 0.7028 - val_loss: 0.0508
# Epoch 2/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6623 - loss: 0.0564 - val_accuracy: 0.7047 - val_loss: 0.0501
# Epoch 3/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6740 - loss: 0.0551 - val_accuracy: 0.7045 - val_loss: 0.0509
# Epoch 4/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6816 - loss: 0.0537 - val_accuracy: 0.6980 - val_loss: 0.0515
# Epoch 5/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6792 - loss: 0.0538 - val_accuracy: 0.6995 - val_loss: 0.0508
# ...

# %%
test_loss, test_acc = ann_pca.evaluate(X_test_pca, y_test, verbose=0)
print(f"\nANN PCA Accuracy: {test_acc:.4f}")

y_pred_ann_pca = ann_pca.predict(X_test_pca)
y_pred_labels_ann_pca = np.argmax(y_pred_ann_pca, axis=1)
y_true_labels_ann_pca = np.argmax(y_test, axis=1)

print("\nClassification Report:")
print(classification_report(y_true_labels_ann_pca, y_pred_labels_ann_pca, target_names=label_encoder.classes_))
# Out:
# ANN PCA Accuracy: 0.6981
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           CH       0.60      0.74      0.66      1000
#           CU       0.88      0.72      0.79      1000
#           FC       0.73      0.73      0.73      1000
#           FF       0.78      0.70      0.74      1000
#           FS       0.77      0.61      0.68      1000
#           SI       0.67      0.71      0.69      1000
#           SL       0.62      0.58      0.60      1000
#           ST       0.63      0.79      0.70      1000
#
#     accuracy                           0.70      8000
#    macro avg       0.71      0.70      0.70      8000
# weighted avg       0.71      0.70      0.70      8000

# %%
cm_ann_pca = confusion_matrix(y_true_labels_ann_pca, y_pred_labels_ann_pca)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_ann_pca, display_labels=classes)
plt.figure(figsize=(8,6))
disp.plot(cmap="Oranges", xticks_rotation=45)
plt.title("ANN Confusion Matrix - PCA")
plt.show()

# %% [markdown]
# This results of ANN and it's confusion matrix once again confirm the inaccuracy of PCA for this application. While the model performs slightly better than KNN, it still becomes highly lossy, confusing similar pitch types. The classification report tells us that PCA is simply not able to describe the variance as well as the models containing the original feature space. The model struggling to accurately make a prediction, and is unable to improve very much. Ultimately we conclude from this that PCA is not a suitable method for the application. One final element to look at for PCA is the plot of pitches within PCA feature space to see if we can get an idea of why PCA is so inaccurate.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[numeric_columns])

pca = PCA(n_components=2)
pc = pca.fit_transform(X_scaled)

df["pc1"] = pc[:,0]
df["pc2"] = pc[:,1]

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x="pc1",
    y="pc2",
    hue="pitch_type",
    palette="tab10",
    alpha=0.6
)
plt.title("Pitch Types Visualized in PCA Feature Space")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
plt.show()

# %% [markdown]
# This image does in fact complete the story of why PCA is an unproductive approach for our sample space. The clusters we observe here are extremely dense, and overlap heavily. It appears that velocity and spin axis trend from our initial graphs carry over here, but are mashed together in such a way that we lose precision and the model becomes unable to differentiate similar pitch types to a much further extent.

# %% [markdown]
# # Ensemble of ANN and KNN
#
# We return now to our original models, and ask the question: can we achieve a higher accuracy than either model individually by combining them together?
#
# We know that each model, KNN and ANN, tends to accurately classify four-seam fastballs, sinkers, cutters and curves well. We see that among the most obviously overlapping pitch types, changeups and splitters, KNN favors splitters and ANN favors changeups. Another notable fact is the consistent struggle with sliders. This issue will be further addressed. We hope that by combining these models predictions together, we can find a higher accuracy for all pitch labeling.
#
# In order to do this, we must alter the way we consider KNN. Instead of using the majority vote of neighbors to determine labeling, we want a probability instead. This probability is compared against the ANN probability to decide the final label.

# %%
p_ann = ann.predict(X_test_s)
p_knn = knn.predict_proba(X_test_s)

# Ensemble weighting
alpha = 0.5
p_ens = alpha * p_knn + (1 - alpha) * p_ann

y_pred_ens = np.argmax(p_ens, axis=1)
y_true_ens = np.argmax(y_test, axis=1)

acc_ens = accuracy_score(y_true_ens, y_pred_ens)
print(f"\nEnsemble Accuracy (alpha={alpha}): {acc_ens:.4f}")

print("\nClassification Report:")
print(classification_report(y_true_ens, y_pred_ens, target_names=label_encoder.classes_))
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Ensemble Accuracy (alpha=0.5): 0.8431
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           CH       0.78      0.79      0.78      1000
#           CU       0.91      0.92      0.91      1000
#           FC       0.79      0.81      0.80      1000
#           FF       0.92      0.94      0.93      1000
#           FS       0.83      0.82      0.83      1000
#           SI       0.92      0.88      0.90      1000
#           SL       0.75      0.69      0.72      1000
#           ST       0.85      0.90      0.87      1000
#
#     accuracy                           0.84      8000
#    macro avg       0.84      0.84      0.84      8000
# weighted avg       0.84      0.84      0.84      8000

# %% [markdown]
# We see that the answer to our question is yes, combining the models into one ensemble does yield a higher accuracy.
#
# We consider each model equally, with alpha = .5 as this value was ultimately the value that resulted in the highest accuracy. This means that each probability is weighed equally, and the model that is more confident will be selected for labeling.
#
# The confusion matrix can be considered once again to observe where the combined model is wrong.

# %%
cm_ens = confusion_matrix(y_true_ens, y_pred_ens)

disp = ConfusionMatrixDisplay(confusion_matrix=cm_ens, display_labels=classes)
plt.figure(figsize=(8,6))
disp.plot(cmap="Reds", xticks_rotation=45)
plt.title("Ensemble Confusion Matrix")
plt.show()

# %% [markdown]
# The model is indeed more accurate overall, but as we examine the individual pitch types, we observe an interesting result. This model is never more accurate than the more accurate model between KNN and ANN for any individual pitch type. In other words, for any given pitch type this model is always between the KNN and ANN accuracy.
#
# This behavior results from each model doing better with specific pitch types, receiving a pitch that it struggles to decisively classify, and labeling it based on narrow margins. In some of those cases, the other model more confidently labels that same pitch incorrectly. This leads to the ensemble model classifying pitches based on the highest confidence between models, which is correct more often in general.

# %% [markdown]
# # Conclusion
#
# The results of our models prove our hypothesis correct, and tell a larger story of how classification challenges arise in these types of machine learning models. Our initial hypothesis was that each model would struggle to differentiate pitches that had large feature relationship overlap. During visualization we could see very clear similarities and overlap between clusters. Without  yet diving too far into why certain pitch types in particular might be misclassified so often, we can explore the fact that any pitch cluster that had large overlap with other pitch clusters struggled more than pitch types that were more independently clustered.
#
# This is an expected outcome in machine learning, as classes with similar features are more likely to be misidentified. The visualization for the data led us to believe that CH/FS, FC/SL, SL/ST groups would be confused the most. This ended up being exactly the case, with changeups and splitters being a recurring theme in the models, as ANN and KNN favored opposite pitches between the two.
#
# Let us finally address what makes splitters and changeups confused, and oppositely so between ANN and KNN. The reality is that these pitches are oftentimes essentially the same. Jomboy Media breaks down exactly how and why these pitches can be considered the same in so many ways in the following video: https://youtube.com/shorts/l8y0FlNzXX0?si=mPXYkQjNHKWjZbvy. In short, the grip used to throw both pitches, as well as release point are very similar. This results in a few types of potential movement. Some pitches will have a higher spin rate, resulting in a sharp drop, while others have a low spin rate causing a tumble through the air as it drops. Regardless of the exact mechanics that pitchers use to execute the pitches, the results is two distinct labels that describe a very similar result.
#
# Sliders are a uniquely poor performing pitch. Throughout all three models and during PCA, it was clear that sliders were not accurately classified compared to other pitch types, and were primarily confused with cutters and sweepers. The visualization of the data perfectly displays why this occured, as sliders are simply very similar to those other pitch types. In baseball terms, sliders are a type of breaking pitch that moves laterally towards the pitcher's glove side. Sliders move faster than other types of breaking pitches like curves, and this results in a fast moving, laterally breaking pitch. Sweepers are considered a type of slider, moving slightly slower, and with more lateral movement. Knowing this context gives us clarity on why these pitches are confused. Cutters are slightly different, as they are literally a "cut fastball" which dashes to the pitcher's glove side very late. They are typically faster than a slider in an individual pitcher arsenal, but given the full context of the dataset, it is understandable that these pitch types are confused as well.
#
# What we can ultimately gather from this exercise in machine learning is twofold. First, we were able to successfully implement a sequence of machine learning tasks that aided us in visualizing and classifying pitch data. Using these tasks, we found clear trends within how the models handled the data, and came to conclusions about how pitch classification works, and how it could be optimized. Those conclusions are that pitch classification is a realistic and implementable system that can be highly accurate, but it would be necessary to consider pitcher repertoire to be able to pin point the correct label in many cases where a pitch could belong to multiple classes.
#
# An important fact to keep in mind is that for CH/FS and SL/FC/ST, the models are not confusing the pitch for other pitches that behave significantly different. The models are simply struggling to differentiate similar pitch types that could fit into either category. The naming of pitch types is not a scientific process. In many cases, a pitch that one player calls a changeup, another calls a splitter. MLB is wise to handle this with multiple layers of classification, most importantly including a pitcher specific layer. We are confidently able to distinguish behavior and features of varying pitch types, but what is important is selecting the label that is most relevant given the context of which pitcher is throwing the ball. A generic pitch model such as ours performing with an accuracy of 84% is very good when we consider this context.
